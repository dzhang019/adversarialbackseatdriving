# %%
import pandas as pd
import json
from pathlib import Path

# %%
path = Path("runs/poscon_negcon_20260323_233220/steering_generations/qualitative_20260326_151041.json")

# %%
rows = json.loads(path.read_text())

# %%
row = rows[0]

# %%
pd.set_option("display.max_colwidth", None)

# %%
table = row["baseline_top_logits_table"]
df = pd.DataFrame(table)

# %%
df
# Out:
#                                                                                                                         step_0  \
# rank_1                        {'token': 'I', 'id': 40, 'logit': 24.0, 'probability': 0.5237551203962308, 'is_generated': True}
# rank_2                 {'token': 'Here', 'id': 8586, 'logit': 23.5, 'probability': 0.31767353870179565, 'is_generated': False}
# rank_3                   {'token': '**', 'id': 334, 'logit': 22.125, 'probability': 0.0803204491232255, 'is_generated': False}
# rank_4                   {'token': 'It', 'id': 2181, 'logit': 21.5, 'probability': 0.04299243833698456, 'is_generated': False}
# rank_5               {'token': 'Once', 'id': 12805, 'logit': 20.75, 'probability': 0.02030818989117204, 'is_generated': False}
# rank_6                {'token': 'Let', 'id': 10267, 'logit': 19.5, 'probability': 0.005818393819368412, 'is_generated': False}
# ...
